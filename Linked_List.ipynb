# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravravan/DSA/blob/main/Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self,value):
    self.data = value
    self.next = None

# %%
a = Node(1)

# %%
print(a)
# Out:
# <__main__.Node object at 0x7905ca410830>

# %%
print(a.data)
# Out:
# 1

# %%
print(a.next)
# Out:
# None

# %%
b = Node(2)
c = Node(3)

# %%
print(b.data)
print(c.data)
# Out:
# 2
# 3

# %% [markdown]
# #creating a Linked List

# %%
id(a)
# Out:
# 133065775056944

# %%
id(b)
# Out:
# 133065774552592

# %%
id(c)
# Out:
# 133065774550864

# %%
a.next = b
b.next= c

# %%
print(a.next)
# Out:
# <__main__.Node object at 0x7905ca395610>

# %%
int(0x7905ca395610)
# Out:
# 133065774552592

# %%
print(b.next)
# Out:
# <__main__.Node object at 0x7905ca394f50>

# %%
int(0x7905ca394f50)
# Out:
# 133065774550864

# %%
class Node:
  def __init__(self,value):
    self.data = value
    self.next = None

# %%
class LinkedList:

  def __init__(self):
    #empty LinkedList
    self.head = None
    #count the number of nodes in Linked List
    self.n = 0

  def __len__(self):
    return self.n

  def insert_head(self,value):

    #new node
    new_node = Node(value)

    #create connection
    new_node.next =self.head

    #reassign head
    self.head = new_node

    #increment n
    self.n = self.n + 1

# %%
L  = LinkedList()

# %%
print(L)
# Out:
# <__main__.LinkedList object at 0x7905ca3b1400>

# %%
len(L)
# Out:
# 0

# %%
L.insert_head(1)
L.insert_head(2)
L.insert_head(3)
L.insert_head(4)
L.insert_head(5)

# %%
len(L)
# Out:
# 5
